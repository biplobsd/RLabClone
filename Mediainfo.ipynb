# %%
#@markdown <h3>⬅️ Upload config</h3>
import subprocess, shlex
from google.colab import files
from os import path as _p

def runSh(args, *, output=False, shell=False):
    if not shell:
        if output:
            proc = subprocess.Popen(  # nosec
                shlex.split(args), stdout=subprocess.PIPE, stderr=subprocess.STDOUT
            )
            while True:
                output = proc.stdout.readline()
                if output == b"" and proc.poll() is not None:
                    return
                if output:
                    print(output.decode("utf-8").strip())
        return subprocess.run(shlex.split(args)).returncode  # nosec
    else:
        if output:
            return (
                subprocess.run(
                    args,
                    shell=True,  # nosec
                    stdout=subprocess.PIPE,
                    stderr=subprocess.STDOUT,
                )
                .stdout.decode("utf-8")
                .strip()
            )
        return subprocess.run(args, shell=True).returncode  # nosec

def checkAvailable(path_="", userPath=False):

    if path_ == "":
        return False
    else:
        return (
            _p.exists(path_)
            if not userPath
            else _p.exists(f"/usr/local/sessionSettings/{path_}")
        )

if not checkAvailable("/etc/apt/sources.list.d/mkvtoolnix.download.list"):
    # !wget -q -O - https://mkvtoolnix.download/gpg-pub-moritzbunkus.txt | sudo apt-key add - && echo "deb https://mkvtoolnix.download/ubuntu/ bionic main" > /etc/apt/sources.list.d/mkvtoolnix.download.list && sudo apt update && sudo apt install mkvtoolnix mkvtoolnix-gui
if not checkAvailable("/root/.config/rclone"):  
    # !mkdir -p -m 666 /root/.config/rclone && curl -s https://rclone.org/install.sh | sudo bash -s beta
try:
    print("Select config file (rclone.conf) from your computer.")
    uploadedFileName = files.upload().keys()
    if len(uploadedFileName) > 1:
        for fn in uploadedFileName:
            runSh(f'rm -f "/content/{fn}"')
        print("Please only upload a single config file.")
    elif len(uploadedFileName) == 0:
        print("File upload cancelled.")
    else:
        for fn in uploadedFileName:
            if checkAvailable(f"/content/{fn}"):
                runSh(
                    f'mv -f "/content/{fn}" /root/.config/rclone/rclone.conf'
                )
                runSh("chmod 666 /root/.config/rclone/rclone.conf")
                runSh('rm -f "/content/{fn}"')
                print("Uploaded file successfully.")

except:
    print("Upload process Error.")
# Out:
# Select config file (rclone.conf) from your computer.
#      <input type="file" id="files-b6ebe609-b817-4e51-a502-e87e85684cb4" name="files[]" multiple disabled />
#      <output id="result-b6ebe609-b817-4e51-a502-e87e85684cb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rclone.conf to rclone.conf
# Uploaded file successfully.

# %%
# !rclone copy "tdTdnRa3:Movies/Batman Trilogy UHD/The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1.mkv" /content/wk -c --stats-one-line --stats=5s -v
# !rclone move "/content/wk/The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1.mkv" "tdTdnRa3:Movies/Batman Trilogy UHD/" -c --stats-one-line --stats=5s -v
# Out:
# 2019/10/05 21:32:11 INFO  :   213.012M / 63.108 GBytes, 0%, 46.190 MBytes/s, ETA 23m14s
# 2019/10/05 21:32:16 INFO  :   524.902M / 63.108 GBytes, 1%, 54.615 MBytes/s, ETA 19m33s
# 2019/10/05 21:32:21 INFO  :   858.387M / 63.108 GBytes, 1%, 58.749 MBytes/s, ETA 18m5s
# 2019/10/05 21:32:26 INFO  :     1.109G / 63.108 GBytes, 2%, 57.929 MBytes/s, ETA 18m15s
# 2019/10/05 21:32:31 INFO  :     1.337G / 63.108 GBytes, 2%, 55.622 MBytes/s, ETA 18m57s
# 2019/10/05 21:32:36 INFO  :     1.593G / 63.108 GBytes, 3%, 55.081 MBytes/s, ETA 19m3s
# 2019/10/05 21:32:41 INFO  :     1.872G / 63.108 GBytes, 3%, 55.389 MBytes/s, ETA 18m52s
# 2019/10/05 21:32:46 INFO  :     2.102G / 63.108 GBytes, 3%, 54.352 MBytes/s, ETA 19m9s
# 2019/10/05 21:32:51 INFO  :     2.322G / 63.108 GBytes, 4%, 53.305 MBytes/s, ETA 19m27s
# 2019/10/05 21:32:56 INFO  :     2.588G / 63.108 GBytes, 4%, 53.423 MBytes/s, ETA 19m20s
# 2019/10/05 21:33:01 INFO  :     2.862G / 63.108 GBytes, 5%, 53.671 MBytes/s, ETA 19m9s
# 2019/10/05 21:33:06 INFO  :     3.128G / 63.108 GBytes, 5%, 53.731 MBytes/s, ETA 19m3s
# 2019/10/05 21:33:11 INFO  :     3.390G / 63.108 GBytes, 5%, 53.722 MBytes/s, ETA 18m58s
# 2019/10/05 21:33:16 INFO  :     3.661G / 63.108 GBytes, 6%, 53.857 MBytes/s, ETA 18m50s
# 2019/10/05 21:33:21 INFO  :     3.929G / 63.108 GBytes, 6%, 53.919 MBytes/s, ETA 18m43s
# 2019/10/05 21:33:26 INFO  :     4.212G / 63.108 GBytes, 7%, 54.175 MBytes/s, ETA 18m33s
# 2019/10/05 21:33:31 INFO  :     4.464G / 63.108 GBytes, 7%, 54.024 MBytes/s, ETA 18m31s
# 2019/10/05 21:33:36 INFO  :     4.710G / 63.108 GBytes, 7%, 53.820 MBytes/s, ETA 18m31s
# 2019/10/05 21:33:41 INFO  :     4.991G / 63.108 GBytes, 8%, 54.022 MBytes/s, ETA 18m21s
# 2019/10/05 21:33:46 INFO  :     5.271G / 63.108 GBytes, 8%, 54.181 MBytes/s, ETA 18m13s
# 2019/10/05 21:33:51 INFO  :     5.554G / 63.108 GBytes, 9%, 54.363 MBytes/s, ETA 18m4s
# 2019/10/05 21:33:56 INFO  :     5.788G / 63.108 GBytes, 9%, 54.073 MBytes/s, ETA 18m5s
# 2019/10/05 21:34:01 INFO  :     6.035G / 63.108 GBytes, 10%, 53.923 MBytes/s, ETA 18m3s
# 2019/10/05 21:34:06 INFO  :     6.265G / 63.108 GBytes, 10%, 53.632 MBytes/s, ETA 18m5s
# 2019/10/05 21:34:11 INFO  :     6.513G / 63.108 GBytes, 10%, 53.518 MBytes/s, ETA 18m2s
# 2019/10/05 21:34:16 INFO  :     6.750G / 63.108 GBytes, 11%, 53.329 MBytes/s, ETA 18m2s
# 2019/10/05 21:34:21 INFO  :     7.066G / 63.108 GBytes, 11%, 53.751 MBytes/s, ETA 17m47s
# 2019/10/05 21:34:26 INFO  :     7.349G / 63.108 GBytes, 12%, 53.900 MBytes/s, ETA 17m39s
# 2019/10/05 21:34:31 INFO  :     7.608G / 63.108 GBytes, 12%, 53.874 MBytes/s, ETA 17m34s
# 2019/10/05 21:34:36 INFO  :     7.854G / 63.108 GBytes, 12%, 53.755 MBytes/s, ETA 17m32s
# 2019/10/05 21:34:41 INFO  :     8.091G / 63.108 GBytes, 13%, 53.587 MBytes/s, ETA 17m31s
# 2019/10/05 21:34:46 INFO  :     8.321G / 63.108 GBytes, 13%, 53.386 MBytes/s, ETA 17m30s
# 2019/10/05 21:34:51 INFO  :     8.594G / 63.108 GBytes, 14%, 53.463 MBytes/s, ETA 17m24s
# 2019/10/05 21:34:56 INFO  :     8.849G / 63.108 GBytes, 14%, 53.425 MBytes/s, ETA 17m19s
# 2019/10/05 21:35:01 INFO  :     9.104G / 63.108 GBytes, 14%, 53.387 MBytes/s, ETA 17m15s
# 2019/10/05 21:35:06 INFO  :     9.374G / 63.108 GBytes, 15%, 53.443 MBytes/s, ETA 17m9s
# 2019/10/05 21:35:11 INFO  :     9.610G / 63.108 GBytes, 15%, 53.307 MBytes/s, ETA 17m7s
# 2019/10/05 21:35:16 INFO  :     9.860G / 63.108 GBytes, 16%, 53.251 MBytes/s, ETA 17m3s
# 2019/10/05 21:35:21 INFO  :    10.103G / 63.108 GBytes, 16%, 53.158 MBytes/s, ETA 17m1s
# 2019/10/05 21:35:26 INFO  :    10.364G / 63.108 GBytes, 16%, 53.168 MBytes/s, ETA 16m55s
# 2019/10/05 21:35:31 INFO  :    10.675G / 63.108 GBytes, 17%, 53.423 MBytes/s, ETA 16m45s
# 2019/10/05 21:35:36 INFO  :    10.931G / 63.108 GBytes, 17%, 53.399 MBytes/s, ETA 16m40s
# 2019/10/05 21:35:41 INFO  :    11.192G / 63.108 GBytes, 18%, 53.404 MBytes/s, ETA 16m35s
# 2019/10/05 21:35:46 INFO  :    11.442G / 63.108 GBytes, 18%, 53.354 MBytes/s, ETA 16m31s
# 2019/10/05 21:35:51 INFO  :    11.708G / 63.108 GBytes, 19%, 53.377 MBytes/s, ETA 16m26s
# 2019/10/05 21:35:56 INFO  :    11.981G / 63.108 GBytes, 19%, 53.434 MBytes/s, ETA 16m19s
# 2019/10/05 21:36:01 INFO  :    12.243G / 63.108 GBytes, 19%, 53.438 MBytes/s, ETA 16m14s
# 2019/10/05 21:36:06 INFO  :    12.475G / 63.108 GBytes, 20%, 53.314 MBytes/s, ETA 16m12s
# 2019/10/05 21:36:11 INFO  :    12.694G / 63.108 GBytes, 20%, 53.142 MBytes/s, ETA 16m11s
# 2019/10/05 21:36:16 INFO  :    12.954G / 63.108 GBytes, 21%, 53.143 MBytes/s, ETA 16m6s
# 2019/10/05 21:36:21 INFO  :    13.234G / 63.108 GBytes, 21%, 53.224 MBytes/s, ETA 15m59s
# 2019/10/05 21:36:26 INFO  :    13.476G / 63.108 GBytes, 21%, 53.156 MBytes/s, ETA 15m56s
# 2019/10/05 21:36:31 INFO  :    13.649G / 63.108 GBytes, 22%, 52.820 MBytes/s, ETA 15m58s
# 2019/10/05 21:36:36 INFO  :    13.891G / 63.108 GBytes, 22%, 52.761 MBytes/s, ETA 15m55s
# 2019/10/05 21:36:41 INFO  :    14.143G / 63.108 GBytes, 22%, 52.738 MBytes/s, ETA 15m50s
# 2019/10/05 21:36:46 INFO  :    14.374G / 63.108 GBytes, 23%, 52.641 MBytes/s, ETA 15m47s
# 2019/10/05 21:36:51 INFO  :    14.627G / 63.108 GBytes, 23%, 52.625 MBytes/s, ETA 15m43s
# 2019/10/05 21:36:56 INFO  :    14.894G / 63.108 GBytes, 24%, 52.661 MBytes/s, ETA 15m37s
# 2019/10/05 21:37:01 INFO  :    15.064G / 63.108 GBytes, 24%, 52.357 MBytes/s, ETA 15m39s
# 2019/10/05 21:37:06 INFO  :    15.194G / 63.108 GBytes, 24%, 51.931 MBytes/s, ETA 15m44s
# 2019/10/05 21:37:11 INFO  :    15.433G / 63.108 GBytes, 24%, 51.879 MBytes/s, ETA 15m41s
# 2019/10/05 21:37:16 INFO  :    15.686G / 63.108 GBytes, 25%, 51.878 MBytes/s, ETA 15m36s
# 2019/10/05 21:37:21 INFO  :    15.974G / 63.108 GBytes, 25%, 51.991 MBytes/s, ETA 15m28s
# 2019/10/05 21:37:26 INFO  :    16.163G / 63.108 GBytes, 26%, 51.784 MBytes/s, ETA 15m28s
# 2019/10/05 21:37:31 INFO  :    16.419G / 63.108 GBytes, 26%, 51.793 MBytes/s, ETA 15m23s
# 2019/10/05 21:37:36 INFO  :    16.679G / 63.108 GBytes, 26%, 51.816 MBytes/s, ETA 15m17s
# 2019/10/05 21:37:41 INFO  :    16.921G / 63.108 GBytes, 27%, 51.783 MBytes/s, ETA 15m13s
# 2019/10/05 21:37:46 INFO  :    17.182G / 63.108 GBytes, 27%, 51.807 MBytes/s, ETA 15m7s
# 2019/10/05 21:37:51 INFO  :    17.439G / 63.108 GBytes, 28%, 51.820 MBytes/s, ETA 15m2s
# 2019/10/05 21:37:56 INFO  :    17.708G / 63.108 GBytes, 28%, 51.866 MBytes/s, ETA 14m56s
# 2019/10/05 21:38:01 INFO  :    17.993G / 63.108 GBytes, 29%, 51.958 MBytes/s, ETA 14m49s
# 2019/10/05 21:38:06 INFO  :    18.249G / 63.108 GBytes, 29%, 51.965 MBytes/s, ETA 14m43s
# 2019/10/05 21:38:11 INFO  :    18.550G / 63.108 GBytes, 29%, 52.096 MBytes/s, ETA 14m35s
# 2019/10/05 21:38:16 INFO  :    18.815G / 63.108 GBytes, 30%, 52.128 MBytes/s, ETA 14m30s
# 2019/10/05 21:38:21 INFO  :    19.058G / 63.108 GBytes, 30%, 52.095 MBytes/s, ETA 14m25s
# 2019/10/05 21:38:26 INFO  :    19.311G / 63.108 GBytes, 31%, 52.091 MBytes/s, ETA 14m20s
# 2019/10/05 21:38:31 INFO  :    19.602G / 63.108 GBytes, 31%, 52.190 MBytes/s, ETA 14m13s
# 2019/10/05 21:38:36 INFO  :    19.874G / 63.108 GBytes, 31%, 52.233 MBytes/s, ETA 14m7s
# 2019/10/05 21:38:41 INFO  :    20.134G / 63.108 GBytes, 32%, 52.246 MBytes/s, ETA 14m2s
# 2019/10/05 21:38:46 INFO  :    20.370G / 63.108 GBytes, 32%, 52.198 MBytes/s, ETA 13m58s
# 2019/10/05 21:38:51 INFO  :    20.636G / 63.108 GBytes, 33%, 52.227 MBytes/s, ETA 13m52s
# 2019/10/05 21:38:56 INFO  :    20.905G / 63.108 GBytes, 33%, 52.260 MBytes/s, ETA 13m46s
# 2019/10/05 21:39:01 INFO  :    21.161G / 63.108 GBytes, 34%, 52.263 MBytes/s, ETA 13m41s
# 2019/10/05 21:39:06 INFO  :    21.433G / 63.108 GBytes, 34%, 52.303 MBytes/s, ETA 13m35s
# 2019/10/05 21:39:11 INFO  :    21.638G / 63.108 GBytes, 34%, 52.182 MBytes/s, ETA 13m33s
# 2019/10/05 21:39:16 INFO  :    21.860G / 63.108 GBytes, 35%, 52.105 MBytes/s, ETA 13m30s
# 2019/10/05 21:39:21 INFO  :    22.105G / 63.108 GBytes, 35%, 52.081 MBytes/s, ETA 13m26s
# 2019/10/05 21:39:26 INFO  :    22.347G / 63.108 GBytes, 35%, 52.053 MBytes/s, ETA 13m21s
# 2019/10/05 21:39:31 INFO  :    22.595G / 63.108 GBytes, 36%, 52.039 MBytes/s, ETA 13m17s
# 2019/10/05 21:39:36 INFO  :    22.874G / 63.108 GBytes, 36%, 52.096 MBytes/s, ETA 13m10s
# 2019/10/05 21:39:41 INFO  :    23.173G / 63.108 GBytes, 37%, 52.197 MBytes/s, ETA 13m3s
# 2019/10/05 21:39:46 INFO  :    23.435G / 63.108 GBytes, 37%, 52.212 MBytes/s, ETA 12m58s
# 2019/10/05 21:39:51 INFO  :    23.683G / 63.108 GBytes, 38%, 52.196 MBytes/s, ETA 12m53s
# 2019/10/05 21:39:56 INFO  :    23.958G / 63.108 GBytes, 38%, 52.241 MBytes/s, ETA 12m47s
# 2019/10/05 21:40:01 INFO  :    24.212G / 63.108 GBytes, 38%, 52.239 MBytes/s, ETA 12m42s
# 2019/10/05 21:40:06 INFO  :    24.409G / 63.108 GBytes, 39%, 52.115 MBytes/s, ETA 12m40s
# 2019/10/05 21:40:11 INFO  :    24.676G / 63.108 GBytes, 39%, 52.141 MBytes/s, ETA 12m34s
# 2019/10/05 21:40:16 INFO  :    24.966G / 63.108 GBytes, 40%, 52.215 MBytes/s, ETA 12m28s
# 2019/10/05 21:40:21 INFO  :    25.255G / 63.108 GBytes, 40%, 52.285 MBytes/s, ETA 12m21s
# 2019/10/05 21:40:26 INFO  :    25.536G / 63.108 GBytes, 40%, 52.339 MBytes/s, ETA 12m15s
# 2019/10/05 21:40:31 INFO  :    25.787G / 63.108 GBytes, 41%, 52.329 MBytes/s, ETA 12m10s
# 2019/10/05 21:40:36 INFO  :    26.048G / 63.108 GBytes, 41%, 52.340 MBytes/s, ETA 12m5s
# 2019/10/05 21:40:41 INFO  :    26.312G / 63.108 GBytes, 42%, 52.356 MBytes/s, ETA 11m59s
# 2019/10/05 21:40:46 INFO  :    26.546G / 63.108 GBytes, 42%, 52.314 MBytes/s, ETA 11m55s
# 2019/10/05 21:40:51 INFO  :    26.784G / 63.108 GBytes, 42%, 52.281 MBytes/s, ETA 11m51s
# 2019/10/05 21:40:56 INFO  :    27.020G / 63.108 GBytes, 43%, 52.243 MBytes/s, ETA 11m47s
# 2019/10/05 21:41:01 INFO  :    27.292G / 63.108 GBytes, 43%, 52.275 MBytes/s, ETA 11m41s
# 2019/10/05 21:41:06 INFO  :    27.552G / 63.108 GBytes, 44%, 52.284 MBytes/s, ETA 11m36s
# 2019/10/05 21:41:11 INFO  :    27.784G / 63.108 GBytes, 44%, 52.241 MBytes/s, ETA 11m32s
# 2019/10/05 21:41:16 INFO  :    28.071G / 63.108 GBytes, 44%, 52.301 MBytes/s, ETA 11m25s
# 2019/10/05 21:41:21 INFO  :    28.331G / 63.108 GBytes, 45%, 52.308 MBytes/s, ETA 11m20s
# 2019/10/05 21:41:26 INFO  :    28.599G / 63.108 GBytes, 45%, 52.331 MBytes/s, ETA 11m15s
# 2019/10/05 21:41:31 INFO  :    28.879G / 63.108 GBytes, 46%, 52.376 MBytes/s, ETA 11m9s
# 2019/10/05 21:41:36 INFO  :    29.179G / 63.108 GBytes, 46%, 52.455 MBytes/s, ETA 11m2s
# 2019/10/05 21:41:41 INFO  :    29.441G / 63.108 GBytes, 47%, 52.466 MBytes/s, ETA 10m57s
# 2019/10/05 21:41:46 INFO  :    29.723G / 63.108 GBytes, 47%, 52.512 MBytes/s, ETA 10m51s
# 2019/10/05 21:41:51 INFO  :    29.963G / 63.108 GBytes, 47%, 52.484 MBytes/s, ETA 10m46s
# 2019/10/05 21:41:56 INFO  :    30.226G / 63.108 GBytes, 48%, 52.494 MBytes/s, ETA 10m41s
# 2019/10/05 21:42:01 INFO  :    30.499G / 63.108 GBytes, 48%, 52.523 MBytes/s, ETA 10m35s
# 2019/10/05 21:42:06 INFO  :    30.743G / 63.108 GBytes, 49%, 52.502 MBytes/s, ETA 10m31s
# 2019/10/05 21:42:11 INFO  :    30.982G / 63.108 GBytes, 49%, 52.472 MBytes/s, ETA 10m26s
# 2019/10/05 21:42:16 INFO  :    31.250G / 63.108 GBytes, 50%, 52.492 MBytes/s, ETA 10m21s
# 2019/10/05 21:42:21 INFO  :    31.491G / 63.108 GBytes, 50%, 52.467 MBytes/s, ETA 10m17s
# 2019/10/05 21:42:26 INFO  :    31.743G / 63.108 GBytes, 50%, 52.459 MBytes/s, ETA 10m12s
# 2019/10/05 21:42:31 INFO  :    32.036G / 63.108 GBytes, 51%, 52.521 MBytes/s, ETA 10m5s
# 2019/10/05 21:42:36 INFO  :    32.290G / 63.108 GBytes, 51%, 52.517 MBytes/s, ETA 10m
# 2019/10/05 21:42:41 INFO  :    32.511G / 63.108 GBytes, 52%, 52.459 MBytes/s, ETA 9m57s
# 2019/10/05 21:42:46 INFO  :    32.760G / 63.108 GBytes, 52%, 52.448 MBytes/s, ETA 9m52s
# 2019/10/05 21:42:51 INFO  :    32.976G / 63.108 GBytes, 52%, 52.384 MBytes/s, ETA 9m49s
# 2019/10/05 21:42:56 INFO  :    33.269G / 63.108 GBytes, 53%, 52.442 MBytes/s, ETA 9m42s
# 2019/10/05 21:43:01 INFO  :    33.542G / 63.108 GBytes, 53%, 52.470 MBytes/s, ETA 9m37s
# 2019/10/05 21:43:06 INFO  :    33.790G / 63.108 GBytes, 54%, 52.457 MBytes/s, ETA 9m32s
# 2019/10/05 21:43:11 INFO  :    34.026G / 63.108 GBytes, 54%, 52.426 MBytes/s, ETA 9m28s
# 2019/10/05 21:43:16 INFO  :    34.280G / 63.108 GBytes, 54%, 52.423 MBytes/s, ETA 9m23s
# 2019/10/05 21:43:21 INFO  :    34.528G / 63.108 GBytes, 55%, 52.411 MBytes/s, ETA 9m18s
# 2019/10/05 21:43:26 INFO  :    34.812G / 63.108 GBytes, 55%, 52.452 MBytes/s, ETA 9m12s
# 2019/10/05 21:43:31 INFO  :    35.060G / 63.108 GBytes, 56%, 52.440 MBytes/s, ETA 9m7s
# 2019/10/05 21:43:36 INFO  :    35.278G / 63.108 GBytes, 56%, 52.385 MBytes/s, ETA 9m4s
# 2019/10/05 21:43:41 INFO  :    35.500G / 63.108 GBytes, 56%, 52.334 MBytes/s, ETA 9m
# 2019/10/05 21:43:46 INFO  :    35.815G / 63.108 GBytes, 57%, 52.422 MBytes/s, ETA 8m53s
# 2019/10/05 21:43:51 INFO  :    36.085G / 63.108 GBytes, 57%, 52.442 MBytes/s, ETA 8m47s
# 2019/10/05 21:43:56 INFO  :    36.366G / 63.108 GBytes, 58%, 52.478 MBytes/s, ETA 8m41s
# 2019/10/05 21:44:01 INFO  :    36.585G / 63.108 GBytes, 58%, 52.425 MBytes/s, ETA 8m38s
# 2019/10/05 21:44:06 INFO  :    36.845G / 63.108 GBytes, 58%, 52.430 MBytes/s, ETA 8m32s
# 2019/10/05 21:44:11 INFO  :    37.097G / 63.108 GBytes, 59%, 52.425 MBytes/s, ETA 8m28s
# 2019/10/05 21:44:16 INFO  :    37.339G / 63.108 GBytes, 59%, 52.404 MBytes/s, ETA 8m23s
# 2019/10/05 21:44:21 INFO  :    37.622G / 63.108 GBytes, 60%, 52.443 MBytes/s, ETA 8m17s
# 2019/10/05 21:44:26 INFO  :    37.870G / 63.108 GBytes, 60%, 52.432 MBytes/s, ETA 8m12s
# 2019/10/05 21:44:31 INFO  :    38.099G / 63.108 GBytes, 60%, 52.394 MBytes/s, ETA 8m8s
# 2019/10/05 21:44:36 INFO  :    38.355G / 63.108 GBytes, 61%, 52.394 MBytes/s, ETA 8m3s
# 2019/10/05 21:44:41 INFO  :    38.595G / 63.108 GBytes, 61%, 52.373 MBytes/s, ETA 7m59s
# 2019/10/05 21:44:46 INFO  :    38.847G / 63.108 GBytes, 62%, 52.369 MBytes/s, ETA 7m54s
# 2019/10/05 21:44:51 INFO  :    39.108G / 63.108 GBytes, 62%, 52.376 MBytes/s, ETA 7m49s
# 2019/10/05 21:44:56 INFO  :    39.364G / 63.108 GBytes, 62%, 52.376 MBytes/s, ETA 7m44s
# 2019/10/05 21:45:01 INFO  :    39.615G / 63.108 GBytes, 63%, 52.369 MBytes/s, ETA 7m39s
# 2019/10/05 21:45:06 INFO  :    39.888G / 63.108 GBytes, 63%, 52.392 MBytes/s, ETA 7m33s
# 2019/10/05 21:45:11 INFO  :    40.149G / 63.108 GBytes, 64%, 52.399 MBytes/s, ETA 7m28s
# 2019/10/05 21:45:16 INFO  :    40.399G / 63.108 GBytes, 64%, 52.392 MBytes/s, ETA 7m23s
# 2019/10/05 21:45:21 INFO  :    40.630G / 63.108 GBytes, 64%, 52.359 MBytes/s, ETA 7m19s
# 2019/10/05 21:45:26 INFO  :    40.908G / 63.108 GBytes, 65%, 52.388 MBytes/s, ETA 7m13s
# 2019/10/05 21:45:31 INFO  :    41.169G / 63.108 GBytes, 65%, 52.394 MBytes/s, ETA 7m8s
# 2019/10/05 21:45:36 INFO  :    41.420G / 63.108 GBytes, 66%, 52.389 MBytes/s, ETA 7m3s
# 2019/10/05 21:45:41 INFO  :    41.688G / 63.108 GBytes, 66%, 52.404 MBytes/s, ETA 6m58s
# 2019/10/05 21:45:46 INFO  :    41.939G / 63.108 GBytes, 66%, 52.397 MBytes/s, ETA 6m53s
# 2019/10/05 21:45:51 INFO  :    42.248G / 63.108 GBytes, 67%, 52.464 MBytes/s, ETA 6m47s
# 2019/10/05 21:45:56 INFO  :    42.489G / 63.108 GBytes, 67%, 52.445 MBytes/s, ETA 6m42s
# 2019/10/05 21:46:01 INFO  :    42.737G / 63.108 GBytes, 68%, 52.435 MBytes/s, ETA 6m37s
# 2019/10/05 21:46:06 INFO  :    42.975G / 63.108 GBytes, 68%, 52.412 MBytes/s, ETA 6m33s
# 2019/10/05 21:46:11 INFO  :    43.220G / 63.108 GBytes, 68%, 52.399 MBytes/s, ETA 6m28s
# 2019/10/05 21:46:16 INFO  :    43.448G / 63.108 GBytes, 69%, 52.366 MBytes/s, ETA 6m24s
# 2019/10/05 21:46:21 INFO  :    43.724G / 63.108 GBytes, 69%, 52.390 MBytes/s, ETA 6m18s
# 2019/10/05 21:46:26 INFO  :    43.935G / 63.108 GBytes, 70%, 52.337 MBytes/s, ETA 6m15s
# 2019/10/05 21:46:31 INFO  :    44.183G / 63.108 GBytes, 70%, 52.327 MBytes/s, ETA 6m10s
# 2019/10/05 21:46:36 INFO  :    44.425G / 63.108 GBytes, 70%, 52.312 MBytes/s, ETA 6m5s
# 2019/10/05 21:46:41 INFO  :    44.659G / 63.108 GBytes, 71%, 52.287 MBytes/s, ETA 6m1s
# 2019/10/05 21:46:46 INFO  :    44.920G / 63.108 GBytes, 71%, 52.294 MBytes/s, ETA 5m56s
# 2019/10/05 21:46:51 INFO  :    45.171G / 63.108 GBytes, 72%, 52.288 MBytes/s, ETA 5m51s
# 2019/10/05 21:46:56 INFO  :    45.446G / 63.108 GBytes, 72%, 52.312 MBytes/s, ETA 5m45s
# 2019/10/05 21:47:01 INFO  :    45.687G / 63.108 GBytes, 72%, 52.294 MBytes/s, ETA 5m41s
# 2019/10/05 21:47:06 INFO  :    45.968G / 63.108 GBytes, 73%, 52.324 MBytes/s, ETA 5m35s
# 2019/10/05 21:47:11 INFO  :    46.229G / 63.108 GBytes, 73%, 52.330 MBytes/s, ETA 5m30s
# 2019/10/05 21:47:16 INFO  :    46.500G / 63.108 GBytes, 74%, 52.348 MBytes/s, ETA 5m24s
# 2019/10/05 21:47:21 INFO  :    46.790G / 63.108 GBytes, 74%, 52.386 MBytes/s, ETA 5m18s
# 2019/10/05 21:47:26 INFO  :    47.045G / 63.108 GBytes, 75%, 52.385 MBytes/s, ETA 5m13s
# 2019/10/05 21:47:31 INFO  :    47.290G / 63.108 GBytes, 75%, 52.374 MBytes/s, ETA 5m9s
# 2019/10/05 21:47:36 INFO  :    47.515G / 63.108 GBytes, 75%, 52.339 MBytes/s, ETA 5m5s
# 2019/10/05 21:47:41 INFO  :    47.772G / 63.108 GBytes, 76%, 52.341 MBytes/s, ETA 5m
# 2019/10/05 21:47:46 INFO  :    48.025G / 63.108 GBytes, 76%, 52.338 MBytes/s, ETA 4m55s
# 2019/10/05 21:47:51 INFO  :    48.250G / 63.108 GBytes, 76%, 52.305 MBytes/s, ETA 4m50s
# 2019/10/05 21:47:56 INFO  :    48.551G / 63.108 GBytes, 77%, 52.354 MBytes/s, ETA 4m44s
# 2019/10/05 21:48:01 INFO  :    48.826G / 63.108 GBytes, 77%, 52.375 MBytes/s, ETA 4m39s
# 2019/10/05 21:48:06 INFO  :    49.085G / 63.108 GBytes, 78%, 52.378 MBytes/s, ETA 4m34s
# 2019/10/05 21:48:11 INFO  :    49.353G / 63.108 GBytes, 78%, 52.391 MBytes/s, ETA 4m28s
# 2019/10/05 21:48:16 INFO  :    49.626G / 63.108 GBytes, 79%, 52.410 MBytes/s, ETA 4m23s
# 2019/10/05 21:48:21 INFO  :    49.870G / 63.108 GBytes, 79%, 52.397 MBytes/s, ETA 4m18s
# 2019/10/05 21:48:26 INFO  :    50.126G / 63.108 GBytes, 79%, 52.397 MBytes/s, ETA 4m13s
# 2019/10/05 21:48:31 INFO  :    50.350G / 63.108 GBytes, 80%, 52.364 MBytes/s, ETA 4m9s
# 2019/10/05 21:48:36 INFO  :    50.560G / 63.108 GBytes, 80%, 52.317 MBytes/s, ETA 4m5s
# 2019/10/05 21:48:41 INFO  :    50.823G / 63.108 GBytes, 81%, 52.325 MBytes/s, ETA 4m
# 2019/10/05 21:48:46 INFO  :    51.087G / 63.108 GBytes, 81%, 52.333 MBytes/s, ETA 3m55s
# 2019/10/05 21:48:51 INFO  :    51.395G / 63.108 GBytes, 81%, 52.387 MBytes/s, ETA 3m48s
# 2019/10/05 21:48:56 INFO  :    51.673G / 63.108 GBytes, 82%, 52.409 MBytes/s, ETA 3m43s
# 2019/10/05 21:49:01 INFO  :    51.941G / 63.108 GBytes, 82%, 52.421 MBytes/s, ETA 3m38s
# 2019/10/05 21:49:06 INFO  :    52.194G / 63.108 GBytes, 83%, 52.419 MBytes/s, ETA 3m33s
# 2019/10/05 21:49:11 INFO  :    52.470G / 63.108 GBytes, 83%, 52.439 MBytes/s, ETA 3m27s
# 2019/10/05 21:49:16 INFO  :    52.720G / 63.108 GBytes, 84%, 52.432 MBytes/s, ETA 3m22s
# 2019/10/05 21:49:21 INFO  :    52.968G / 63.108 GBytes, 84%, 52.425 MBytes/s, ETA 3m18s
# 2019/10/05 21:49:26 INFO  :    53.222G / 63.108 GBytes, 84%, 52.423 MBytes/s, ETA 3m13s
# 2019/10/05 21:49:31 INFO  :    53.468G / 63.108 GBytes, 85%, 52.413 MBytes/s, ETA 3m8s
# 2019/10/05 21:49:36 INFO  :    53.712G / 63.108 GBytes, 85%, 52.401 MBytes/s, ETA 3m3s
# 2019/10/05 21:49:41 INFO  :    53.962G / 63.108 GBytes, 86%, 52.396 MBytes/s, ETA 2m58s
# 2019/10/05 21:49:46 INFO  :    54.209G / 63.108 GBytes, 86%, 52.388 MBytes/s, ETA 2m53s
# 2019/10/05 21:49:51 INFO  :    54.474G / 63.108 GBytes, 86%, 52.396 MBytes/s, ETA 2m48s
# 2019/10/05 21:49:56 INFO  :    54.678G / 63.108 GBytes, 87%, 52.346 MBytes/s, ETA 2m44s
# 2019/10/05 21:50:01 INFO  :    54.903G / 63.108 GBytes, 87%, 52.318 MBytes/s, ETA 2m40s
# 2019/10/05 21:50:06 INFO  :    55.154G / 63.108 GBytes, 87%, 52.313 MBytes/s, ETA 2m35s
# 2019/10/05 21:50:11 INFO  :    55.388G / 63.108 GBytes, 88%, 52.292 MBytes/s, ETA 2m31s
# 2019/10/05 21:50:16 INFO  :    55.612G / 63.108 GBytes, 88%, 52.264 MBytes/s, ETA 2m26s
# 2019/10/05 21:50:21 INFO  :    55.849G / 63.108 GBytes, 88%, 52.246 MBytes/s, ETA 2m22s
# 2019/10/05 21:50:26 INFO  :    56.106G / 63.108 GBytes, 89%, 52.248 MBytes/s, ETA 2m17s
# 2019/10/05 21:50:31 INFO  :    56.354G / 63.108 GBytes, 89%, 52.242 MBytes/s, ETA 2m12s
# 2019/10/05 21:50:36 INFO  :    56.608G / 63.108 GBytes, 90%, 52.241 MBytes/s, ETA 2m7s
# 2019/10/05 21:50:41 INFO  :    56.886G / 63.108 GBytes, 90%, 52.261 MBytes/s, ETA 2m1s
# 2019/10/05 21:50:46 INFO  :    57.106G / 63.108 GBytes, 90%, 52.230 MBytes/s, ETA 1m57s
# 2019/10/05 21:50:51 INFO  :    57.309G / 63.108 GBytes, 91%, 52.182 MBytes/s, ETA 1m53s
# 2019/10/05 21:50:56 INFO  :    57.562G / 63.108 GBytes, 91%, 52.180 MBytes/s, ETA 1m48s
# 2019/10/05 21:51:01 INFO  :    57.827G / 63.108 GBytes, 92%, 52.190 MBytes/s, ETA 1m43s
# 2019/10/05 21:51:06 INFO  :    58.090G / 63.108 GBytes, 92%, 52.197 MBytes/s, ETA 1m38s
# 2019/10/05 21:51:11 INFO  :    58.323G / 63.108 GBytes, 92%, 52.177 MBytes/s, ETA 1m33s
# 2019/10/05 21:51:16 INFO  :    58.590G / 63.108 GBytes, 93%, 52.188 MBytes/s, ETA 1m28s
# 2019/10/05 21:51:21 INFO  :    58.859G / 63.108 GBytes, 93%, 52.201 MBytes/s, ETA 1m23s
# 2019/10/05 21:51:26 INFO  :    59.083G / 63.108 GBytes, 94%, 52.174 MBytes/s, ETA 1m19s
# 2019/10/05 21:51:31 INFO  :    59.321G / 63.108 GBytes, 94%, 52.159 MBytes/s, ETA 1m14s
# 2019/10/05 21:51:36 INFO  :    59.575G / 63.108 GBytes, 94%, 52.158 MBytes/s, ETA 1m9s
# 2019/10/05 21:51:41 INFO  :    59.815G / 63.108 GBytes, 95%, 52.146 MBytes/s, ETA 1m4s
# 2019/10/05 21:51:46 INFO  :    60.043G / 63.108 GBytes, 95%, 52.123 MBytes/s, ETA 1m
# 2019/10/05 21:51:51 INFO  :    60.304G / 63.108 GBytes, 96%, 52.128 MBytes/s, ETA 55s
# 2019/10/05 21:51:56 INFO  :    60.579G / 63.108 GBytes, 96%, 52.146 MBytes/s, ETA 49s
# 2019/10/05 21:52:01 INFO  :    60.839G / 63.108 GBytes, 96%, 52.150 MBytes/s, ETA 44s
# 2019/10/05 21:52:06 INFO  :    61.099G / 63.108 GBytes, 97%, 52.154 MBytes/s, ETA 39s
# 2019/10/05 21:52:11 INFO  :    61.347G / 63.108 GBytes, 97%, 52.149 MBytes/s, ETA 34s
# 2019/10/05 21:52:16 INFO  :    61.567G / 63.108 GBytes, 98%, 52.120 MBytes/s, ETA 30s
# 2019/10/05 21:52:21 INFO  :    61.818G / 63.108 GBytes, 98%, 52.117 MBytes/s, ETA 25s
# 2019/10/05 21:52:26 INFO  :    62.073G / 63.108 GBytes, 98%, 52.117 MBytes/s, ETA 20s
# 2019/10/05 21:52:31 INFO  :    62.327G / 63.108 GBytes, 99%, 52.117 MBytes/s, ETA 15s
# 2019/10/05 21:52:36 INFO  :    62.601G / 63.108 GBytes, 99%, 52.133 MBytes/s, ETA 9s
# 2019/10/05 21:52:41 INFO  :    62.864G / 63.108 GBytes, 100%, 52.140 MBytes/s, ETA 4s
# 2019/10/05 21:52:46 INFO  :    63.108G / 63.108 GBytes, 100%, 52.131 MBytes/s, ETA 0s
# 2019/10/05 21:52:49 INFO  : The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1.mkv: Copied (new)
# 2019/10/05 21:52:49 INFO  : The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1.mkv: Deleted
# 2019/10/05 21:52:49 INFO  :    63.108G / 63.108 GBytes, 100%, 52.015 MBytes/s, ETA 0s

# %%
#@markdown <h3>⬅️ Media Info</h3>
Path = "/content/drive/Shared drives/TDN Share Drive/Movies/Blade.Runner.2049.2017.2160p.BluRay.x265.10bit.HDR.DTS-HD.MA.TrueHD.7.1.Atmos-SWTYBLZ/Blade.Runner.2049.2017.2160p.BluRay.x265.10bit.HDR.DTS-HD.MA.TrueHD.7.1.Atmos-SWTYBLZ.mkv" #@param {type:"string"}
Save_nfo = False #@param {type:"boolean"}
Save_txt = False #@param {type:"boolean"}
import os, uuid, re, IPython
import ipywidgets as widgets
import time

from glob import glob
from IPython.display import HTML, clear_output
from google.colab import output, drive

def mediainfo():
  display(HTML("<br>"))
#   print(Path.split("/")[::-1][0])
  display(HTML("<br>"))
#   media = !mediainfo "$Path"
#   media = "\n".join(media).replace(os.path.dirname(Path)+"/", "")
  get_ipython().system_raw("""mediainfo --LogFile="/root/.nfo" "$Path" """)
  with open('/root/.nfo', 'r') as file:
    media = file.read()
    media = media.replace(os.path.dirname(Path)+"/", "")
  print(media)
  get_ipython().system_raw("rm -f '/root/.nfo'")
  if Save_nfo:
    nfo = Path.rpartition('.')[0] + ".nfo"
    if os.path.exists(nfo):
      get_ipython().system_raw("rm -f '$nfo'")
    # !curl -s https://pastebin.com/raw/TApKLQfM -o "$nfo"
    with open(nfo, 'a+') as file:
      file.write("\n\n")
      file.write(media)
  
  if Save_txt:
    txt = Path.rpartition('.')[0] + ".txt"
    if os.path.exists(txt):
      get_ipython().system_raw("rm -f '$txt'")
    # !curl -s https://pastebin.com/raw/TApKLQfM -o "$txt"
    with open(txt, 'a+') as file:
      file.write("\n\n")
      file.write(media)

while not os.path.exists("/content/drive"):
  try:
    drive.mount("/content/drive")
    clear_output(wait=True)
  except:
    clear_output()
    
if not os.path.exists("/usr/bin/mediainfo"):
  get_ipython().system_raw("apt-get install mediainfo")
  
mediainfo()

# %%
# !mkvpropedit "/content/Avatar.2009.Extended.UHD.Re-Grade.4000nit.2160p.HEVC.HDR.IVA(RUS.UKR.ENG).ExKinoRay.mkv" --edit track:@12 --set flag-default=0 --edit track:@20 --set flag-default=1
# !mkvmerge -o "/content/fixed/fixed-Skyfall.2012.1080p.Bluray.x264.DTS-HDMA.5.1-DTOne.mkv" --default-duration 0:23.976fps /content/wk/Skyfall.2012.1080p.Bluray.x264.DTS-HDMA.5.1-DTOne.mkv

# %%
# !mkvinfo "/content/wk/The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1.mkv"
# !mkvpropedit "/content/wk/The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1.mkv" --edit track:@2 --set flag-default=1
# Out:
# + EBML head
# |+ EBML version: 1
# |+ EBML read version: 1
# |+ Maximum EBML ID length: 4
# |+ Maximum EBML size length: 8
# |+ Document type: matroska
# |+ Document type version: 4
# |+ Document type read version: 2
# + Segment: size 67761893063
# |+ Seek head (subentries will be skipped)
# |+ EBML void: size 3988
# |+ Segment information
# | + Timestamp scale: 1000000
# | + Multiplexing application: libebml v1.3.5 + libmatroska v1.4.8
# | + Writing application: mkvmerge v19.0.0 ('Brave Captain') 64-bit
# | + Duration: 02:32:12.256000000
# | + Date: Mon Jan 15 19:20:23 2018 UTC
# | + Title: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# | + Segment UID: 0xda 0x35 0x4c 0xf2 0xd4 0x93 0x7d 0x03 0x9a 0xcd 0x29 0x5a 0xe4 0x2c 0xe3 0xcc
# |+ Tracks
# | + Track
# |  + Track number: 1 (track ID for mkvmerge & mkvextract: 0)
# |  + Track UID: 13395905456465480298
# |  + Track type: video
# |  + Lacing flag: 0
# |  + Codec ID: V_MPEGH/ISO/HEVC
# |  + Language: und
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Video track
# |   + Pixel width: 3840
# |   + Pixel height: 2160
# |   + Display width: 3840
# |   + Display height: 2160
# |  + Codec's private data: size 753 (HEVC profile: Main 10 @L5.1)
# |  + Default duration: 00:00:00.041708333 (23.976 frames/fields per second for a video track)
# | + Track
# |  + Track number: 2 (track ID for mkvmerge & mkvextract: 1)
# |  + Track UID: 2178472035084346105
# |  + Track type: audio
# |  + Codec ID: A_DTS
# |  + Default duration: 00:00:00.010666667 (93.750 frames/fields per second for a video track)
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# |   + Bit depth: 24
# |  + Default track flag: 1
# | + Track
# |  + Track number: 3 (track ID for mkvmerge & mkvextract: 2)
# |  + Track UID: 1581467126717668325
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_AC3
# |  + Default duration: 00:00:00.032000000 (31.250 frames/fields per second for a video track)
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 2
# | + Track
# |  + Track number: 4 (track ID for mkvmerge & mkvextract: 3)
# |  + Track UID: 15515578884200176085
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_DTS
# |  + Default duration: 00:00:00.010666667 (93.750 frames/fields per second for a video track)
# |  + Language: fre
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# |   + Bit depth: 16
# | + Track
# |  + Track number: 5 (track ID for mkvmerge & mkvextract: 4)
# |  + Track UID: 5781704575054059432
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_DTS
# |  + Default duration: 00:00:00.010666667 (93.750 frames/fields per second for a video track)
# |  + Language: ger
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# |   + Bit depth: 16
# | + Track
# |  + Track number: 6 (track ID for mkvmerge & mkvextract: 5)
# |  + Track UID: 591378683837553921
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_AC3
# |  + Default duration: 00:00:00.032000000 (31.250 frames/fields per second for a video track)
# |  + Language: ita
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# | + Track
# |  + Track number: 7 (track ID for mkvmerge & mkvextract: 6)
# |  + Track UID: 772340427684488240
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_AC3
# |  + Default duration: 00:00:00.032000000 (31.250 frames/fields per second for a video track)
# |  + Language: spa
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# | + Track
# |  + Track number: 8 (track ID for mkvmerge & mkvextract: 7)
# |  + Track UID: 15143412791978924470
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_AC3
# |  + Default duration: 00:00:00.032000000 (31.250 frames/fields per second for a video track)
# |  + Language: cze
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# | + Track
# |  + Track number: 9 (track ID for mkvmerge & mkvextract: 8)
# |  + Track UID: 11315731485453144806
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_AC3
# |  + Default duration: 00:00:00.032000000 (31.250 frames/fields per second for a video track)
# |  + Language: hun
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# | + Track
# |  + Track number: 10 (track ID for mkvmerge & mkvextract: 9)
# |  + Track UID: 8537516669353937293
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_AC3
# |  + Default duration: 00:00:00.032000000 (31.250 frames/fields per second for a video track)
# |  + Language: pol
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# | + Track
# |  + Track number: 11 (track ID for mkvmerge & mkvextract: 10)
# |  + Track UID: 2144351154324323401
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_AC3
# |  + Default duration: 00:00:00.032000000 (31.250 frames/fields per second for a video track)
# |  + Language: rus
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# | + Track
# |  + Track number: 12 (track ID for mkvmerge & mkvextract: 11)
# |  + Track UID: 8867249910481701732
# |  + Track type: audio
# |  + Default track flag: 0
# |  + Codec ID: A_AC3
# |  + Default duration: 00:00:00.032000000 (31.250 frames/fields per second for a video track)
# |  + Language: jpn
# |  + Name: The.Dark.Knight.2008.2160p.BluRay.REMUX.HEVC.DTS-HD.MA.5.1-FGT
# |  + Audio track
# |   + Sampling frequency: 48000
# |   + Channels: 6
# | + Track
# |  + Track number: 13 (track ID for mkvmerge & mkvextract: 12)
# |  + Track UID: 17566531753058772282
# |  + Track type: subtitles
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Name: English-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 14 (track ID for mkvmerge & mkvextract: 13)
# |  + Track UID: 132223101928342369
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: fre
# |  + Name: French-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 15 (track ID for mkvmerge & mkvextract: 14)
# |  + Track UID: 11757403555906755011
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: ger
# |  + Name: German-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 16 (track ID for mkvmerge & mkvextract: 15)
# |  + Track UID: 17800528397258644510
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: ita
# |  + Name: Italian-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 17 (track ID for mkvmerge & mkvextract: 16)
# |  + Track UID: 15144737225801542292
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: spa
# |  + Name: Spanish-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 18 (track ID for mkvmerge & mkvextract: 17)
# |  + Track UID: 9019681309638614255
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: dut
# |  + Name: Dutch-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 19 (track ID for mkvmerge & mkvextract: 18)
# |  + Track UID: 5153816461645188428
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: chi
# |  + Name: Chinese-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 20 (track ID for mkvmerge & mkvextract: 19)
# |  + Track UID: 11487904604735603979
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: chi
# |  + Name: Chinese-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 21 (track ID for mkvmerge & mkvextract: 20)
# |  + Track UID: 3666415288787599644
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: kor
# |  + Name: Korean-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 22 (track ID for mkvmerge & mkvextract: 21)
# |  + Track UID: 4570096771256669369
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: ara
# |  + Name: Arabic-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 23 (track ID for mkvmerge & mkvextract: 22)
# |  + Track UID: 5906638943783547203
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: cze
# |  + Name: Czech-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 24 (track ID for mkvmerge & mkvextract: 23)
# |  + Track UID: 9193882260769139430
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: hrv
# |  + Name: Croatian-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 25 (track ID for mkvmerge & mkvextract: 24)
# |  + Track UID: 9588387749920435505
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: dan
# |  + Name: Danish-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 26 (track ID for mkvmerge & mkvextract: 25)
# |  + Track UID: 1611939452491793275
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: fin
# |  + Name: Finnish-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 27 (track ID for mkvmerge & mkvextract: 26)
# |  + Track UID: 2941149215803804537
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: gre
# |  + Name: Greek-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 28 (track ID for mkvmerge & mkvextract: 27)
# |  + Track UID: 14876724030972179364
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: hun
# |  + Name: Hungarian-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 29 (track ID for mkvmerge & mkvextract: 28)
# |  + Track UID: 2543441098160452722
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: nor
# |  + Name: Norwegian-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 30 (track ID for mkvmerge & mkvextract: 29)
# |  + Track UID: 12886418810962669381
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: pol
# |  + Name: Polish-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 31 (track ID for mkvmerge & mkvextract: 30)
# |  + Track UID: 3324236619140320436
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: por
# |  + Name: Portuguese-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 32 (track ID for mkvmerge & mkvextract: 31)
# |  + Track UID: 5662180648543546773
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: rum
# |  + Name: Romanian-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 33 (track ID for mkvmerge & mkvextract: 32)
# |  + Track UID: 10581772182803545204
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: rus
# |  + Name: Russian-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 34 (track ID for mkvmerge & mkvextract: 33)
# |  + Track UID: 15671694881417906130
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: swe
# |  + Name: Swedish-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 35 (track ID for mkvmerge & mkvextract: 34)
# |  + Track UID: 4835098165023303433
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: fre
# |  + Name: French-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 36 (track ID for mkvmerge & mkvextract: 35)
# |  + Track UID: 11282457603946306412
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: cze
# |  + Name: Czech-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 37 (track ID for mkvmerge & mkvextract: 36)
# |  + Track UID: 3292593944297067297
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: spa
# |  + Name: Spanish-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 38 (track ID for mkvmerge & mkvextract: 37)
# |  + Track UID: 13183271387930716824
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: ita
# |  + Name: Italian-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 39 (track ID for mkvmerge & mkvextract: 38)
# |  + Track UID: 8166905265272577968
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: pol
# |  + Name: Polish-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 40 (track ID for mkvmerge & mkvextract: 39)
# |  + Track UID: 16991745081647602653
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: rus
# |  + Name: Russian-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 41 (track ID for mkvmerge & mkvextract: 40)
# |  + Track UID: 13847165092949230439
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: hun
# |  + Name: Hungarian-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 42 (track ID for mkvmerge & mkvextract: 41)
# |  + Track UID: 4430817500390968399
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: ger
# |  + Name: German-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 43 (track ID for mkvmerge & mkvextract: 42)
# |  + Track UID: 3874216567928821294
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: jpn
# |  + Name: Japanese-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# | + Track
# |  + Track number: 44 (track ID for mkvmerge & mkvextract: 43)
# |  + Track UID: 8582400258570589538
# |  + Track type: subtitles
# |  + Default track flag: 0
# |  + Lacing flag: 0
# |  + Codec ID: S_HDMV/PGS
# |  + Language: jpn
# |  + Name: Japanese-FORCED-PGS
# |  + Content encodings
# |   + Content encoding
# |    + Content compression
# |+ EBML void: size 2166
# |+ Attachments
# | + Attached
# |  + File name: small_cover.jpg
# |  + MIME type: image/jpeg
# |  + File data: size 5037
# |  + File UID: 12850349338779084969
# | + Attached
# |  + File name: small_cover_land.jpg
# |  + MIME type: image/jpeg
# |  + File data: size 8562
# |  + File UID: 14647914030849807319
# | + Attached
# |  + File name: cover.jpg
# |  + MIME type: image/jpeg
# |  + File data: size 23754
# |  + File UID: 71043742961338667
# | + Attached
# |  + File name: cover_land.jpg
# |  + MIME type: image/jpeg
# |  + File data: size 24552
# |  + File UID: 11947643356579727525
# |+ Chapters
# | + Edition entry
# |  + Edition flag hidden: 0
# |  + Edition flag default: 0
# |  + Edition UID: 1411720839898055902
# |  + Chapter atom
# |   + Chapter UID: 12572501680389988320
# |   + Chapter time start: 00:00:00.000000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 1
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 942218438097111625
# |   + Chapter time start: 00:06:25.927000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 2
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 13389272660577323583
# |   + Chapter time start: 00:10:36.135000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 3
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 5400294351571777482
# |   + Chapter time start: 00:13:52.540000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 4
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 1796198629965424731
# |   + Chapter time start: 00:17:54.156000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 5
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 14451084488633909831
# |   + Chapter time start: 00:21:39.298000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 6
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 6019365835925390019
# |   + Chapter time start: 00:26:09.985000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 7
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 411127905561835283
# |   + Chapter time start: 00:29:36.232000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 8
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 6390511052265668304
# |   + Chapter time start: 00:31:42.442000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 9
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 14472362086990948982
# |   + Chapter time start: 00:37:49.016000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 10
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 4798706225484463842
# |   + Chapter time start: 00:43:34.028000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 11
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 14379145000706813988
# |   + Chapter time start: 00:46:39.505000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 12
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 540159247895907203
# |   + Chapter time start: 00:48:57.726000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 13
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 8955458605581756062
# |   + Chapter time start: 00:53:19.404000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 14
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 2552585369457901382
# |   + Chapter time start: 00:57:15.598000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 15
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 747870217739038447
# |   + Chapter time start: 00:59:26.312000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 16
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 3905682364523984376
# |   + Chapter time start: 01:03:59.544000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 17
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 390518469066688782
# |   + Chapter time start: 01:08:23.516000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 18
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 7991781138015351839
# |   + Chapter time start: 01:10:48.285000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 19
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 16782523385844561136
# |   + Chapter time start: 01:14:24.877000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 20
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 16430705884991175479
# |   + Chapter time start: 01:18:05.597000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 21
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 18416739141562746444
# |   + Chapter time start: 01:22:22.395000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 22
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 10668255846342289513
# |   + Chapter time start: 01:24:48.541000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 23
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 5002386002246018432
# |   + Chapter time start: 01:30:48.401000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 24
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 7188120418313445736
# |   + Chapter time start: 01:34:04.930000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 25
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 7443268307020353881
# |   + Chapter time start: 01:39:57.741000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 26
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 18310058792975720886
# |   + Chapter time start: 01:42:05.452000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 27
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 10543705548806981746
# |   + Chapter time start: 01:44:59.876000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 28
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 13494662124193642416
# |   + Chapter time start: 01:47:00.831000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 29
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 2474644212192043875
# |   + Chapter time start: 01:51:09.871000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 30
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 12840709736588411105
# |   + Chapter time start: 01:54:14.597000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 31
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 180778077309446107
# |   + Chapter time start: 01:57:03.975000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 32
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 9290343457256224201
# |   + Chapter time start: 02:00:14.207000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 33
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 5147093041132280330
# |   + Chapter time start: 02:03:37.535000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 34
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 12139762450947041079
# |   + Chapter time start: 02:09:07.573000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 35
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 7090067799046929985
# |   + Chapter time start: 02:12:27.272000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 36
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 10091607469322336826
# |   + Chapter time start: 02:15:22.739000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 37
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 171359941411060272
# |   + Chapter time start: 02:19:58.640000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 38
# |    + Chapter language: eng
# |  + Chapter atom
# |   + Chapter UID: 1688514557225169842
# |   + Chapter time start: 02:24:26.658000000
# |   + Chapter flag hidden: 0
# |   + Chapter flag enabled: 1
# |   + Chapter display
# |    + Chapter string: Chapter 39
# |    + Chapter language: eng
# |+ EBML void: size 101
# |+ Cluster

# %%
# !mkvinfo "/content/drive/Shared drives/TDN Share Drive/Movies/007.James.Bond.Complete.Collection.1962-2015.1080p.Bluray.x264.DTS-HDMA-DTOne/You.Only.Live.Twice.1967.1080p.Bluray.x264.DTS-HDMA.5.1-DTOne.mkv"
# !for i in /content/wk/*.mkv; do mkvmerge -o /content/fixed/fixed-$i --default-duration 0:23.976fps $i; done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
